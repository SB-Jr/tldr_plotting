# %% [markdown]
# # Seaborn vs Matplotlib
#
# As you have just read, Seaborn is complimentary to Matplotlib and it specifically targets statistical data visualization.
#
# ## “If matplotlib “tries to make easy things easy and hard things possible”, seaborn tries to make a well-defined set of hard things easy too.”

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# working with DataFrames doesn’t go quite as smoothly with Matplotlib, which can be annoying if you’re doing exploratory analysis with Pandas. And that’s exactly what Seaborn addresses: the plotting functions operate on DataFrames and arrays that contain a whole dataset.

# %%
#ALl the data
fifa_data_path = 'data/fifa.csv'
flight_delay_data_path = 'data/flight_delays.csv'
ign_scores_data_path = 'data/ign_scores.csv'
insurance_data_path = 'data/insurance.csv'
museum_data_path = 'data/museum_visitors.csv'
candy_data_path = 'data/candy.csv'

# %% [markdown]
# # Seaborn Charts

# %% [markdown]
# ## Line Chart

# %% [markdown]
# Data for chart is the museum data, which tracks monthly visitors for different museums. The index column we will choose for this data is the date.

# %%
museum_df = pd.read_csv(museum_data_path, index_col='Date', parse_dates=True)
museum_df.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# It was stated that a even for the Firehouse Museum took place which popularized the museum. We can track it by using a line graph.

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=museum_df)

# %% [markdown]
# We can see here that the event took place in 2014 near the year's end approximately in between September-October.

# %% [markdown]
# ## Bar Chart and Heatmaps

# %% [markdown]
# Here we will use 2 datasets. First is the flight delay dataset which tracks the flight delays of different airlines in minutes, if its -ve then it denotes it was early. The second dataset is the IGN's game review dataset which gives a general overview of the genre score and the platform on which these genres got a score. We will be using the Month column as the index column for the flight delay dataset and the Platform column as the index for the IGN dataset.

# %%
flight_df = pd.read_csv(flight_delay_data_path, index_col='Month')
flight_df.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %% [markdown]
# Here we can use Bar chart to see which month has the highest amount of delays for the 'NK' airlines.

# %%
plt.figure(figsize=(20,8))
sns.barplot(x=flight_df.index, y = flight_df['NK'])

# %% [markdown]
# This shows that the NK airlines has the max amount of delay in June.

# %% [markdown]
# We can now use a Heatmap to get a quick visualization of the data

# %%
plt.figure(figsize=(20,8))
sns.heatmap(data=flight_df, annot=True)

# %% [markdown]
# With a quick glance we can see that AS airline was always before time and NK airline was always behind time in all the months.

# %% [markdown]
# Now working with the IGN dataset.

# %%
ign_df = pd.read_csv(ign_scores_data_path, index_col='Platform')
ign_df.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %% [markdown]
# Lets look at the average score for racing games for each platform.

# %%
plt.figure(figsize=(20,8))
sns.barplot(x = ign_df.index, y= ign_df['Racing'])

# %% [markdown]
# Similarly we can see the heatmap of all the genres for all the platforms.

# %%
plt.figure(figsize=(20,8))
sns.heatmap(data=ign_df, annot=True)

# %% [markdown]
# ## Scatter Plot, RegPlot, Lmplot and Swarm Plot

# %% [markdown]
# Here we will be working on the insurance data which shows depending on health factors how much an individual has to pay for securing an insurance. Another dataset is about the candy, its price variance based on its property.

# %% [markdown]
# For the insurance dataset we wont be using any index column.<br>
#
# Lets see if there is any relation between the charges payed vs the BMI of a person.

# %%
insurance_df = pd.read_csv(insurance_data_path)
insurance_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x = insurance_df['bmi'], y = insurance_df['charges'])

# %% [markdown]
# This might not exactly show if there is any correlation or not. We can also add a regression line to see if there is any +ve or -ve correlation present or not.

# %%
plt.figure(figsize=(20,8))
sns.regplot(x = insurance_df['bmi'], y = insurance_df['charges'])

# %% [markdown]
# We can also use a color coded scatter plot for showing more info. Here we can see how many of these points correspond to smokers and non-smokers

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x = insurance_df['bmi'], y = insurance_df['charges'], hue=insurance_df['smoker'])

# %% [markdown]
# In the above graph we can see that non-smoker tend to pay less while smoker tend to pay more. This can be further proved using lm plot.

# %%
plt.figure(figsize=(20,8))
sns.lmplot(x = 'bmi', y = 'charges', hue='smoker', data = insurance_df)

# %% [markdown]
# In the above graph the smokers have a more +ve correlation while non-smoker has a small +ve correlation.

# %% [markdown]
# We can also use swarm plot to get this kind of understanding on the data.

# %%
plt.figure(figsize=(20,8))
sns.swarmplot(x = insurance_df['smoker'], y = insurance_df['charges'])

# %% [markdown]
# Here also we can see that smokers pay more than the non smokers and most of non-smokers pay less as the graph is more brad at the bottom than the top

# %% [markdown]
# Now working on the candy data.

# %%
candy_df = pd.read_csv(candy_data_path, index_col='id')
candy_df.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %% [markdown]
# Lets understand how sugar content affects the popularity of the candy

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x = candy_df['sugarpercent'], y = candy_df['winpercent'])

# %% [markdown]
# This doesnt give much of an info to use so lets use the regplot

# %%
plt.figure(figsize=(20,8))
sns.regplot(x = candy_df['sugarpercent'], y = candy_df['winpercent'])

# %% [markdown]
# Here we can see that sugar content is actually almost 0 way correlated to the popularity.

# %% [markdown]
# Now lets see if the candy being chocolate affect price and popularity or not.

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x = candy_df['pricepercent'], y = candy_df['winpercent'], hue=candy_df['chocolate'])

# %%
plt.figure(figsize=(20,8))
sns.lmplot(x = 'pricepercent', y = 'winpercent', hue = 'chocolate', data=candy_df)

# %% [markdown]
# From the above graph we can see that if the candy is chocolate nd costly then it more popular and if it is not chocolate then cheaper candy are more popular(showed using -ve correlation)

# %%
plt.figure(figsize=(20,8))
sns.swarmplot(x=candy_df['chocolate'], y=candy_df['winpercent'])

# %% [markdown]
# Here too the graph shows that chocolate candy are popular which are costly and non-chocoalte candy are popular which are cheaper.
